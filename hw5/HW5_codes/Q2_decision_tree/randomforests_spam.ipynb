# %% [markdown]
# ## Random Forest for Spam
# ### (make sure to have run featurize_spam.py)

# %%
import numpy as np
np.random.seed(1)

import scipy.io
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

from decisiontree import *

# %%
spam_path = "datasets/spam-dataset/spam_data.mat"
data = scipy.io.loadmat(spam_path)
x = data["training_data"]
x = StandardScaler().fit_transform(x)
pca = PCA(n_components=0.90, whiten=True)
pca_fit = pca.fit(x)
x = pca_fit.transform(x)

y = np.squeeze(data["training_labels"])
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=0.2)
x_test = pca.transform(data["test_data"])
print(x.shape,y.shape,x_test.shape)
# Out:
# (3336, 25) (3336,) (5857, 25)

# %%
# %%time
rf = RandomForest(num_trees=5,max_depth=10,header="spam_randomforest_")
rf.fit(x_train, y_train)
# Out:
# 2019-03-26 18:56:37,104	WARNING worker.py:1406 -- WARNING: Not updating worker name since `setproctitle` is not installed. Install this with `pip install setproctitle` (or ray[debug]) to enable monitoring of worker processes.
# 2019-03-26 18:56:37,107	INFO node.py:423 -- Process STDOUT and STDERR is being redirected to /tmp/ray/session_2019-03-26_18-56-37_51776/logs.
# 2019-03-26 18:56:37,217	INFO services.py:363 -- Waiting for redis server at 127.0.0.1:34248 to respond...
# 2019-03-26 18:56:37,332	INFO services.py:363 -- Waiting for redis server at 127.0.0.1:13859 to respond...
# 2019-03-26 18:56:37,337	INFO services.py:760 -- Starting Redis shard with 3.44 GB max memory.
# 2019-03-26 18:56:37,350	INFO services.py:1384 -- Starting the Plasma object store with 5.15 GB memory using /tmp.
# (pid=51799) currently on depth  0
# (pid=51798) currently on depth  0
# (pid=51795) currently on depth  0
# (pid=51801) currently on depth  0
# (pid=51802) currently on depth  0
# (pid=51798) currently on depth  1
# (pid=51799) currently on depth  1
# (pid=51795) currently on depth  1
# (pid=51801) currently on depth  1
# (pid=51801) currently on depth  2
# (pid=51801) currently on depth  3
# (pid=51801) currently on depth  3
# (pid=51801) currently on depth  4
# (pid=51801) currently on depth  4
# (pid=51801) currently on depth  2
# (pid=51801) currently on depth  1
# (pid=51802) currently on depth  1
# (pid=51802) currently on depth  1
# (pid=51795) currently on depth  2
# (pid=51795) currently on depth  3
# (pid=51795) currently on depth  4
# (pid=51795) currently on depth  4
# (pid=51795) currently on depth  5
# (pid=51795) currently on depth  5
# (pid=51799) currently on depth  2
# (pid=51798) currently on depth  2
# (pid=51795) currently on depth  6
# (pid=51801) currently on depth  2
# (pid=51801) currently on depth  3
# (pid=51801) currently on depth  4
# (pid=51801) currently on depth  4
# (pid=51801) currently on depth  5
# (pid=51801) currently on depth  5
# (pid=51801) currently on depth  6
# (pid=51801) currently on depth  6
# (pid=51801) currently on depth  7
# (pid=51801) currently on depth  7
# (pid=51801) currently on depth  8
# (pid=51801) currently on depth  8
# (pid=51801) currently on depth  3
# (pid=51801) currently on depth  2
# (pid=51802) currently on depth  2
# (pid=51802) currently on depth  2
# (pid=51795) currently on depth  7
# (pid=51795) currently on depth  7
# (pid=51798) currently on depth  3
# (pid=51795) currently on depth  8
# (pid=51795) currently on depth  9
# (pid=51795) currently on depth  9
# (pid=51798) currently on depth  4
# (pid=51795) currently on depth  10
# (pid=51795) currently on depth  10
# (pid=51795) currently on depth  8
# (pid=51795) currently on depth  6
# (pid=51795) currently on depth  3
# (pid=51795) currently on depth  2
# (pid=51795) currently on depth  3
# (pid=51795) currently on depth  4
# (pid=51795) currently on depth  5
# (pid=51795) currently on depth  5
# (pid=51795) currently on depth  6
# (pid=51795) currently on depth  6
# (pid=51795) currently on depth  4
# (pid=51795) currently on depth  3
# (pid=51795) currently on depth  1
# (pid=51799) currently on depth  3
# (pid=51799) currently on depth  3
# (pid=51798) currently on depth  5
# (pid=51798) currently on depth  6
# (pid=51801) currently on depth  3
# (pid=51802) currently on depth  3
# (pid=51795) currently on depth  2
# (pid=51798) currently on depth  7
# (pid=51802) currently on depth  4
# (pid=51795) currently on depth  3
# (pid=51799) currently on depth  4
# (pid=51798) currently on depth  8
# (pid=51798) currently on depth  8
# (pid=51795) currently on depth  4
# (pid=51801) currently on depth  4
# (pid=51799) currently on depth  5
# (pid=51799) currently on depth  5
# (pid=51799) currently on depth  6
# (pid=51799) currently on depth  6
# (pid=51799) currently on depth  7
# (pid=51799) currently on depth  8
# (pid=51799) currently on depth  8
# (pid=51799) currently on depth  7
# (pid=51799) currently on depth  4
# (pid=51795) currently on depth  5
# (pid=51795) currently on depth  5
# (pid=51795) currently on depth  6
# (pid=51795) currently on depth  6
# (pid=51795) currently on depth  7
# (pid=51795) currently on depth  8
# (pid=51795) currently on depth  8
# (pid=51795) currently on depth  9
# (pid=51795) currently on depth  9
# (pid=51795) currently on depth  10
# (pid=51795) currently on depth  10
# (pid=51795) currently on depth  7
# (pid=51795) currently on depth  4
# (pid=51802) currently on depth  5
# (pid=51802) currently on depth  5
# (pid=51795) currently on depth  5
# (pid=51798) currently on depth  9
# (pid=51798) currently on depth  9
# (pid=51795) currently on depth  6
# (pid=51795) currently on depth  6
# (pid=51802) currently on depth  6
# (pid=51795) currently on depth  7
# (pid=51795) currently on depth  7
# (pid=51801) currently on depth  5
# (pid=51801) currently on depth  5
# (pid=51802) currently on depth  7
# (pid=51798) currently on depth  10
# (pid=51798) currently on depth  10
# (pid=51798) currently on depth  7
# (pid=51798) currently on depth  6
# (pid=51798) currently on depth  5
# (pid=51798) currently on depth  6
# (pid=51798) currently on depth  6
# (pid=51798) currently on depth  4
# (pid=51798) currently on depth  3
# (pid=51798) currently on depth  4
# (pid=51798) currently on depth  4
# (pid=51798) currently on depth  5
# (pid=51798) currently on depth  5
# (pid=51798) currently on depth  6
# (pid=51798) currently on depth  6
# (pid=51798) currently on depth  2
# (pid=51795) currently on depth  8
# (pid=51795) currently on depth  8
# (pid=51795) currently on depth  9
# (pid=51795) currently on depth  9
# (pid=51802) currently on depth  8
# (pid=51802) currently on depth  8
# (pid=51795) currently on depth  10
# (pid=51795) currently on depth  10
# (pid=51795) currently on depth  5
# (pid=51795) currently on depth  6
# (pid=51795) currently on depth  6
# (pid=51795) currently on depth  7
# (pid=51795) currently on depth  8
# (pid=51795) currently on depth  9
# (pid=51795) currently on depth  9
# (pid=51795) currently on depth  10
# (pid=51795) currently on depth  10
# (pid=51795) currently on depth  8
# (pid=51795) currently on depth  7
# (pid=51795) currently on depth  3
# (pid=51799) currently on depth  5
# (pid=51795) currently on depth  4
# (pid=51795) currently on depth  5
# (pid=51795) currently on depth  5
# (pid=51795) currently on depth  4
# (pid=51795) currently on depth  2
# (pid=51802) currently on depth  9
# (pid=51799) currently on depth  6
# (pid=51799) currently on depth  7
# (pid=51798) currently on depth  3
# (pid=51801) currently on depth  6
# (pid=51801) currently on depth  7
# (pid=51802) currently on depth  10
# (pid=51802) currently on depth  10
# (pid=51802) currently on depth  9
# (pid=51799) currently on depth  7
# (pid=51799) currently on depth  8
# (pid=51799) currently on depth  8
# (pid=51798) currently on depth  4
# (pid=51801) currently on depth  8
# (pid=51801) currently on depth  8
# (pid=51801) currently on depth  7
# (pid=51801) currently on depth  8
# (pid=51801) currently on depth  9
# (pid=51801) currently on depth  9
# (pid=51801) currently on depth  10
# (pid=51801) currently on depth  10
# (pid=51801) currently on depth  8
# (pid=51801) currently on depth  6
# (pid=51802) currently on depth  10
# (pid=51802) currently on depth  10
# (pid=51802) currently on depth  7
# (pid=51802) currently on depth  6
# (pid=51799) currently on depth  9
# (pid=51799) currently on depth  10
# (pid=51799) currently on depth  10
# (pid=51799) currently on depth  9
# (pid=51799) currently on depth  10
# (pid=51799) currently on depth  10
# (pid=51799) currently on depth  6
# (pid=51799) currently on depth  5
# (pid=51802) currently on depth  7
# (pid=51802) currently on depth  7
# (pid=51798) currently on depth  5
# (pid=51798) currently on depth  6
# (pid=51798) currently on depth  6
# (pid=51798) currently on depth  7
# (pid=51795) currently on depth  3
# (pid=51802) currently on depth  8
# (pid=51802) currently on depth  9
# (pid=51802) currently on depth  10
# (pid=51802) currently on depth  10
# (pid=51802) currently on depth  9
# (pid=51802) currently on depth  8
# (pid=51802) currently on depth  9
# (pid=51798) currently on depth  8
# (pid=51798) currently on depth  9
# (pid=51798) currently on depth  9
# (pid=51798) currently on depth  10
# (pid=51798) currently on depth  10
# (pid=51798) currently on depth  8
# (pid=51798) currently on depth  9
# (pid=51798) currently on depth  9
# (pid=51798) currently on depth  10
# (pid=51798) currently on depth  10
# (pid=51798) currently on depth  7
# (pid=51798) currently on depth  5
# (pid=51802) currently on depth  10
# (pid=51802) currently on depth  10
# (pid=51802) currently on depth  9
# (pid=51802) currently on depth  10
# (pid=51802) currently on depth  10
# (pid=51802) currently on depth  4
# (pid=51802) currently on depth  3
# (pid=51798) currently on depth  6
# (pid=51798) currently on depth  7
# (pid=51798) currently on depth  8
# (pid=51798) currently on depth  9
# (pid=51798) currently on depth  9
# (pid=51798) currently on depth  10
# (pid=51798) currently on depth  10
# (pid=51798) currently on depth  8
# (pid=51798) currently on depth  7
# (pid=51798) currently on depth  6
# (pid=51798) currently on depth  7
# (pid=51798) currently on depth  7
# (pid=51798) currently on depth  4
# (pid=51798) currently on depth  3
# (pid=51795) currently on depth  4
# (pid=51801) currently on depth  7
# (pid=51801) currently on depth  8
# (pid=51801) currently on depth  8
# (pid=51801) currently on depth  9
# (pid=51801) currently on depth  9
# (pid=51801) currently on depth  10
# (pid=51801) currently on depth  10
# (pid=51801) currently on depth  7
# (pid=51798) currently on depth  4
# (pid=51798) currently on depth  5
# (pid=51798) currently on depth  6
# (pid=51798) currently on depth  6
# (pid=51798) currently on depth  7
# (pid=51798) currently on depth  7
# (pid=51798) currently on depth  8
# (pid=51798) currently on depth  8
# (pid=51798) currently on depth  5
# (pid=51798) currently on depth  4
# (pid=51795) currently on depth  5
# (pid=51795) currently on depth  6
# (pid=51802) currently on depth  4
# (pid=51799) currently on depth  6
# (pid=51799) currently on depth  6
# (pid=51802) currently on depth  5
# (pid=51802) currently on depth  5
# (pid=51802) currently on depth  6
# (pid=51798) currently on depth  5
# (pid=51795) currently on depth  7
# (pid=51801) currently on depth  8
# (pid=51801) currently on depth  8
# (pid=51802) currently on depth  7
# (pid=51802) currently on depth  7
# (pid=51802) currently on depth  8
# (pid=51802) currently on depth  9
# (pid=51802) currently on depth  9
# (pid=51802) currently on depth  10
# (pid=51802) currently on depth  10
# (pid=51802) currently on depth  8
# (pid=51802) currently on depth  6
# (pid=51802) currently on depth  4
# (pid=51795) currently on depth  8
# (pid=51798) currently on depth  6
# (pid=51795) currently on depth  9
# (pid=51795) currently on depth  10
# (pid=51795) currently on depth  10
# (pid=51795) currently on depth  9
# (pid=51795) currently on depth  10
# (pid=51795) currently on depth  10
# (pid=51795) currently on depth  8
# (pid=51795) currently on depth  7
# (pid=51795) currently on depth  8
# (pid=51795) currently on depth  8
# (pid=51798) currently on depth  7
# (pid=51795) currently on depth  9
# (pid=51795) currently on depth  10
# (pid=51795) currently on depth  10
# (pid=51795) currently on depth  9
# (pid=51795) currently on depth  6
# (pid=51795) currently on depth  5
# (pid=51795) currently on depth  4
# (pid=51801) currently on depth  9
# (pid=51798) currently on depth  8
# (pid=51795) currently on depth  5
# (pid=51801) currently on depth  10
# (pid=51801) currently on depth  10
# (pid=51801) currently on depth  9
# (pid=51798) currently on depth  9
# (pid=51795) currently on depth  6
# (pid=51795) currently on depth  6
# (pid=51795) currently on depth  7
# (pid=51795) currently on depth  7
# (pid=51802) currently on depth  5
# (pid=51798) currently on depth  10
# (pid=51798) currently on depth  10
# (pid=51798) currently on depth  9
# (pid=51798) currently on depth  8
# (pid=51798) currently on depth  7
# (pid=51798) currently on depth  8
# (pid=51798) currently on depth  8
# (pid=51798) currently on depth  9
# (pid=51798) currently on depth  9
# (pid=51798) currently on depth  10
# (pid=51798) currently on depth  10
# (pid=51798) currently on depth  6
# (pid=51795) currently on depth  8
# (pid=51795) currently on depth  8
# (pid=51799) currently on depth  7
# (pid=51795) currently on depth  9
# (pid=51795) currently on depth  9
# (pid=51795) currently on depth  10
# (pid=51795) currently on depth  10
# (pid=51795) currently on depth  5
# (pid=51798) currently on depth  7
# (pid=51798) currently on depth  7
# (pid=51795) currently on depth  6
# (pid=51795) currently on depth  6
# (pid=51801) currently on depth  10
# (pid=51801) currently on depth  10
# (pid=51801) currently on depth  4
# (pid=51801) currently on depth  5
# (pid=51801) currently on depth  6
# (pid=51798) currently on depth  8
# (pid=51798) currently on depth  8
# (pid=51798) currently on depth  9
# (pid=51795) currently on depth  7
# (pid=51795) currently on depth  8
# (pid=51795) currently on depth  9
# (pid=51795) currently on depth  10
# (pid=51795) currently on depth  10
# (pid=51795) currently on depth  9
# (pid=51795) currently on depth  8
# (pid=51795) currently on depth  7
# (pid=51801) currently on depth  7
# (pid=51801) currently on depth  8
# (pid=51801) currently on depth  8
# (pid=51801) currently on depth  9
# (pid=51801) currently on depth  9
# (pid=51801) currently on depth  7
# (pid=51801) currently on depth  6
# (pid=51801) currently on depth  5
# (pid=51801) currently on depth  3
# (pid=51798) currently on depth  10
# (pid=51798) currently on depth  10
# (pid=51798) currently on depth  9
# (pid=51798) currently on depth  5
# (pid=51795) currently on depth  8
# (pid=51795) currently on depth  9
# (pid=51795) currently on depth  9
# (pid=51795) currently on depth  10
# (pid=51795) currently on depth  10
# (pid=51795) currently on depth  8
# (pid=51795) currently on depth  3
# (pid=51798) currently on depth  6
# (pid=51798) currently on depth  6
# (pid=51798) currently on depth  7
# (pid=51798) currently on depth  7
# (pid=51802) currently on depth  6
# (pid=51798) currently on depth  8
# (pid=51798) currently on depth  9
# (pid=51798) currently on depth  10
# (pid=51798) currently on depth  10
# (pid=51798) currently on depth  9
# (pid=51798) currently on depth  8
# (pid=51798) currently on depth  1
# (pid=51801) currently on depth  4
# (pid=51801) currently on depth  4
# (pid=51798) currently on depth  2
# (pid=51798) currently on depth  2
# (pid=51798) currently on depth  3
# (pid=51798) currently on depth  4
# (pid=51798) currently on depth  5
# (pid=51798) currently on depth  5
# (pid=51798) currently on depth  6
# (pid=51798) currently on depth  7
# (pid=51798) currently on depth  8
# (pid=51798) currently on depth  9
# (pid=51798) currently on depth  9
# (pid=51798) currently on depth  10
# (pid=51798) currently on depth  10
# (pid=51798) currently on depth  8
# (pid=51798) currently on depth  7
# (pid=51798) currently on depth  6
# (pid=51798) currently on depth  4
# (pid=51798) currently on depth  3
# (pid=51801) currently on depth  5
# (pid=51799) currently on depth  8
# (pid=51802) currently on depth  7
# (pid=51799) currently on depth  9
# (pid=51801) currently on depth  6
# (pid=51799) currently on depth  10
# (pid=51799) currently on depth  10
# (pid=51799) currently on depth  9
# (pid=51799) currently on depth  10
# (pid=51799) currently on depth  10
# (pid=51799) currently on depth  8
# (pid=51801) currently on depth  7
# (pid=51801) currently on depth  8
# (pid=51801) currently on depth  9
# (pid=51801) currently on depth  10
# (pid=51801) currently on depth  10
# (pid=51801) currently on depth  9
# (pid=51801) currently on depth  10
# (pid=51801) currently on depth  10
# (pid=51801) currently on depth  8
# (pid=51801) currently on depth  9
# (pid=51801) currently on depth  10
# (pid=51801) currently on depth  10
# (pid=51801) currently on depth  9
# (pid=51801) currently on depth  7
# (pid=51801) currently on depth  6
# (pid=51802) currently on depth  8
# (pid=51801) currently on depth  7
# (pid=51801) currently on depth  7
# (pid=51801) currently on depth  8
# (pid=51801) currently on depth  8
# (pid=51801) currently on depth  9
# (pid=51801) currently on depth  10
# (pid=51801) currently on depth  10
# (pid=51801) currently on depth  9
# (pid=51799) currently on depth  9
# (pid=51799) currently on depth  10
# (pid=51799) currently on depth  10
# (pid=51799) currently on depth  9
# (pid=51801) currently on depth  10
# (pid=51801) currently on depth  10
# (pid=51801) currently on depth  5
# (pid=51801) currently on depth  6
# (pid=51801) currently on depth  6
# (pid=51801) currently on depth  7
# (pid=51801) currently on depth  7
# (pid=51801) currently on depth  8
# (pid=51801) currently on depth  9
# (pid=51801) currently on depth  9
# (pid=51801) currently on depth  10
# (pid=51801) currently on depth  10
# (pid=51801) currently on depth  8
# (pid=51802) currently on depth  9
# (pid=51802) currently on depth  10
# (pid=51802) currently on depth  10
# (pid=51802) currently on depth  9
# (pid=51802) currently on depth  10
# (pid=51802) currently on depth  10
# (pid=51802) currently on depth  8
# (pid=51802) currently on depth  7
# (pid=51802) currently on depth  8
# (pid=51802) currently on depth  8
# (pid=51802) currently on depth  6
# (pid=51799) currently on depth  10
# (pid=51799) currently on depth  10
# (pid=51799) currently on depth  7
# (pid=51799) currently on depth  8
# (pid=51799) currently on depth  8
# (pid=51799) currently on depth  9
# (pid=51799) currently on depth  9
# (pid=51802) currently on depth  7
# (pid=51802) currently on depth  8
# (pid=51802) currently on depth  9
# (pid=51802) currently on depth  10
# (pid=51802) currently on depth  10
# (pid=51802) currently on depth  9
# (pid=51802) currently on depth  8
# (pid=51802) currently on depth  7
# (pid=51802) currently on depth  5
# (pid=51799) currently on depth  10
# (pid=51799) currently on depth  10
# (pid=51799) currently on depth  2
# (pid=51799) currently on depth  3
# (pid=51799) currently on depth  4
# (pid=51802) currently on depth  6
# (pid=51802) currently on depth  6
# (pid=51802) currently on depth  7
# (pid=51802) currently on depth  7
# (pid=51799) currently on depth  5
# (pid=51799) currently on depth  6
# (pid=51799) currently on depth  6
# (pid=51799) currently on depth  7
# (pid=51799) currently on depth  7
# (pid=51799) currently on depth  8
# (pid=51799) currently on depth  8
# (pid=51799) currently on depth  5
# (pid=51799) currently on depth  6
# (pid=51799) currently on depth  7
# (pid=51799) currently on depth  7
# (pid=51799) currently on depth  8
# (pid=51799) currently on depth  8
# (pid=51799) currently on depth  9
# (pid=51799) currently on depth  9
# (pid=51799) currently on depth  10
# (pid=51799) currently on depth  10
# (pid=51799) currently on depth  6
# (pid=51799) currently on depth  4
# (pid=51799) currently on depth  3
# (pid=51799) currently on depth  1
# (pid=51799) currently on depth  2
# (pid=51799) currently on depth  3
# (pid=51799) currently on depth  3
# (pid=51799) currently on depth  4
# (pid=51799) currently on depth  4
# (pid=51799) currently on depth  5
# (pid=51799) currently on depth  5
# (pid=51799) currently on depth  6
# (pid=51799) currently on depth  7
# (pid=51799) currently on depth  8
# (pid=51799) currently on depth  9
# (pid=51799) currently on depth  9
# (pid=51799) currently on depth  8
# (pid=51799) currently on depth  7
# CPU times: user 1.17 s, sys: 136 ms, total: 1.3 s
# Wall time: 9.25 s

# %%
# %%time
train_preds = rf.predict(x_train,"train")
print("training accuracy:",np.mean(train_preds==y_train))
val_preds = rf.predict(x_val,"val")
print("validation accuracy:",np.mean(val_preds==y_val))
rf.predict(x_test,"test")
# Out:
# (pid=51799) currently on depth  8
# (pid=51799) currently on depth  8
# (pid=51799) currently on depth  9
# (pid=51799) currently on depth  9
# (pid=51799) currently on depth  10
# (pid=51799) currently on depth  10
# (pid=51799) currently on depth  6
# (pid=51799) currently on depth  2
# training accuracy: 0.6101949025487257
# validation accuracy: 0.6092814371257484
# saved predictions
# CPU times: user 139 ms, sys: 29.4 ms, total: 168 ms
# Wall time: 196 ms
