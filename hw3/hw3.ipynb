# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal
np.random.seed(1)

# %% [markdown]
# I certify
# that all solutions are entirely in my own words and that I have not looked at another
# student’s solutions. I have given credit to all external sources I consulted. Signature below:

# %% [markdown]
# # 2 Isocontours of Normal Distributions

# %%
fig_num2 = 0
def isocontour_plotter1(mean, covariance, title):
    global fig_num2
    random_variable = multivariate_normal(mean, covariance)
    x, y = np.mgrid[-1:1:.01, -1:1:.01]
    pos = np.dstack((x, y))
    fig_num2 += 1
    plt.figure(fig_num2)
    plt.title(title)
    plt.contourf(x, y, random_variable.pdf(pos))   

def isocontour_plotter2(means, covariances, title):
    global fig_num2
    random_variable1 = multivariate_normal(means[0], covariances[0])
    random_variable2 = multivariate_normal(means[1], covariances[1])
    x, y = np.mgrid[-1:1:.01, -1:1:.01]
    pos = np.dstack((x, y))
    fig_num2 += 1
    plt.figure(fig_num2)
    plt.title(title)
    plt.contourf(x, y, 
                 random_variable1.pdf(pos)-random_variable2.pdf(pos))  
    
isocontour_plotter1([1,1], [[1,0],[0,2]], "2a")
isocontour_plotter1([-1,2],[[2,1],[1,3]], "2b")
isocontour_plotter2([[0,2],[2,0]],[[[2,1],[1,1]],[[2,1],[1,1]]], "2c")
isocontour_plotter2([[0,2],[2,0]],[[[2,1],[1,1]],[[2,1],[1,3]]], "2d")
isocontour_plotter2([[1,1],[-1,-1]],[[[2,0],[0,1]],[[2,1],[1,2]]], "2e")

# %% [markdown]
# \pagebreak

# %% [markdown]
# # 3 Eigenvectors of the Gaussian Covariance Matrix

# %%
X1 = np.random.normal(3,9,100)
X2_rv = np.random.normal(4,4,100)
samples = [[x1,x10.5*x2] for ]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-c1cb35249256> in <module>
#       1 X1 = norm(3,9)
# ----> 2 X2 = 0.5*X1 + norm(4,4)
#
# TypeError: unsupported operand type(s) for *: 'float' and 'rv_frozen'
